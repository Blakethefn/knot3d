# %% [markdown]
# # Knot Engine Demo
#
# This notebook shows how to run the analysis pipeline on the bundled trefoil example.

# %%
from pathlib import Path
from main import run_pipeline

run_pipeline(Path('examples/trefoil.json'), Path('out/notebook_trefoil'), modes={'analyze'})
